# %% [markdown]
# <a href="https://colab.research.google.com/github/lenaphamthi/github_colab/blob/master/chapter2_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **BÀI TẬP LẬP TRÌNH CHƯƠNG 2**
#
# Bài 1: Lập trình nhập vào từ bàn phím 2 số nguyên và tính:
#
#
# 1.   Tổng của 2 số
# 2.   Tích của 2 số
# 3.   Hiệu của 2 số
# 4.   Phép chia lấy phần dư của 2 số
# 5.   Phép chia lấy phần nguyên của 2 số
#
# Kết quả xuất ra màn hình

# %%
#Your code here
#Tong cua 2 so nguyen
a = input("a=")
b= input("b=")
a = int(a)
b= int(b)
c=a+b, a-b, a*b, a%b, a//b
print("a+b = " + c, "a-b = " + str(c), "a*b = " +str(c), "a%b = " +str(c), "a//b = " +str(c))
# Out:
# a=3
# b=4
# a+b = (7, -1, 12, 3, 0) a-b = (7, -1, 12, 3, 0) a*b = (7, -1, 12, 3, 0) a%b = (7, -1, 12, 3, 0) a//b = (7, -1, 12, 3, 0)

# %%
#Hieu cua 2 so nguyen
a = input("a=")
b= input("b=")
a = int(a)
b= int(b)
c=a-b
print("a-b =",c)
# Out:
# a=5
# b=2
# a-b = 3

# %%
#Tich cua 2 so nguyen
a = input("a=")
b= input("b=")
a = int(a)
b= int(b)
c=a*b
print("a*b =",c)
# Out:
# a=2
# b=2
# a*b = 4

# %%
#Phep chia lay phan du cua 2 so nguyen
a = input("a=")
b= input("b=")
a = int(a)
b= int(b)
c=a%b
print("a%b =",c)
# Out:
# a=5
# b=2
# a%b = 1

# %%
#Phep chia lay phan nguyen cua 2 so nguyen
a = input("a=")
b= input("b=")
a = int(a)
b= int(b)
c=a//b
print("a//b =",c)
# Out:
# a=5
# b=2
# a//b = 2

# %% [markdown]
# Bài 2: Lập trình nhập vào từ bàn phím 2 số thực và tính:
#
# 1.   Tổng của 2 số
# 2.   Tích của 2 số
# 3.   Hiệu của 2 số
# 4.   Thương của 2 số
#
# Kết quả xuất ra màn hình

# %%
#Your code here
#Tong cua 2 so thuc
a = input("a=")
b= input("b=")
a = float(a)
b= float(b)
c=a+b
print("a+b =",c)
# Out:
# a=0.2
# b=0.5
# a+b = 0.7

# %%
#Hieu cua 2 so thuc
a = input("a=")
b= input("b=")
a = float(a)
b= float(b)
c=a-b
print("a-b =",c)
# Out:
# a=1.5
# b=1.5
# a-b = 0.0

# %%
#Thuong cua 2 so thuc
a = input("a=")
b= input("b=")
a = float(a)
b= float(b)
c=a*b
print("a*b =",c)
# Out:
# a=2.5
# b=2.4
# a*b = 6.0

# %%
#Tich cua 2 so thuc
a = input("a=")
b= input("b=")
a = float(a)
b= float(b)
c=a/b
print("a/b =",c)
# Out:
# a=6.3
# b=2.5
# a/b = 2.52

# %% [markdown]
# Bài 3: (Sử dụng các hàm toán học) Nhập một số từ bàn phím và tính:
#
#
#
# 1.   Trị tuyệt đối
# 2.   Lấy phần nguyên của số
# 3.   Chuyển đổi thành số thực
# 4.   (nhập thêm 1 số từ bàn phím) và tính lũy thừa $ x^y $
# 5.   Tính căn bậc hai
#
# Kết quả xuất ra màn hình

# %%
#Your code here

# %% [markdown]
# Bài 4: Nhập 2 số từ bàn phím và thực hiện các phép so sánh sau giữa 2 số:
#
#
#
# 1.   $ \geq $
# 2.   $ \leq $
# 3.   $ > $
# 4.   $ < $
# 5.   $ \neq $
#
# Kết quả xuất ra màn hình

# %%
#Your code here

# %% [markdown]
# Bài 5: Nhập 1 chuỗi ký tự từ bàn phím:
#
#
#
# 1.   Chuyển thành chuỗi in hoa
# 2.   Chuyển thành chuỗi in thường
#
# Kết quả xuất ra màn hình

# %%
#Your code here

# %% [markdown]
# Bài 6: Xuất ra màn hình 1 chuỗi ký từ nằm trên nhiều hàng (có thể là 1 bài thơ tùy ý bạn lựa chọn)

# %%
#Your code here
